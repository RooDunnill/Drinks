# %% [markdown]
# # Welcome to the Collabrative Drink Rater!
#
# ### Here you can rate the plethora of beverages you have from all around the world in ONE PLACE. Compare your ratings with friends and find out your buddies' favorite drinks.

# %% [markdown]
# #### Setting up the connection to your google drive where you have downloaded the RooDrink.py module. I should have already shared the Drinking folde that has the RooDrink module. If you want a local version just copy the folder and change the names called or the second cell will make a Drinking file for you.

# %%
from google.colab import drive
import os

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Define the path to the specific folder
folder_path = '/content/drive/MyDrive/Drinking'

# Change the current working directory to the folder
if not os.path.exists(folder_path):
    print(f"Folder '{folder_path}' does not exist. Creating it now.")
    os.makedirs(folder_path)

os.chdir(folder_path)
print(f"Current working directory: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Current working directory: /content/drive/MyDrive/Drinking

# %% [markdown]
# ## Once the previous cell is run there will be a Drinking folder in your drive. COPY AND ADD the RooDrink.py file to that folder keeping its name then start at the top and run the cells again

# %%
# %ls #check the files in the folder make sure you see RooDrink.py
# Out:
# bevlist4roo.pkl  DrinkRater.ipynb  __pycache__/  README.txt  RooDrink.py

# %% [markdown]
# ##### for some reason we now have to allow widgets in google colab cause it's a ween

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# ### Now we start!

# %%
#pip install ipympl #just in case you dont have it :) comment back in to use
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.7/515.7 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 36.8 MB/s eta 0:00:00
# ...

# %%
# %matplotlib widget
import RooDrink as rd
import numpy as np

# %% [markdown]
# # Main Plot

# %%
name = ['Guinness','one','three','newdrinkg','Guinness','lighter_fluid'] #add the bevs you drink here
beer = [10,4,5,7,10,1] #add the rating for beer here
wine =[0,6,5,2,1,1] #add the rating for wine here
whiskey = [4,3,9,2,1,1] #add the rating for whiskey here
urname = ['Testone','Testcheese','Testthruwu','Testtwo','Testone','Roo']

#NOTE: YOU HAVE TO ADD A RANKING FOR ALL 3 PER BEV
#Your name has a RANDOM color each run and will appear above your name

rd.DrinkRating(name,beer,wine,whiskey,urname)
# Out:
#                Beer Rating  Wine Rating  Whiskey Rating        User
# Guinness                10            0               4     Testone
# one                      4            6               3  Testcheese
# three                    5            5               9  Testthruwu
# newdrinkg                7            2               2     Testtwo
# Guinness                10            1               1     Testone
# lighter_fluid            1            1               1         Roo
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#You can still use numpy to find max or min values

res = np.max(beer)

res2 = np.max(wine)
print(res)
print(res2)
# Out:
# 10
# 6

# %% [markdown]
# ### Finding the drink by name

# %%
rd.FindDrink("Guinness")
# Out:
#           Beer Rating  Wine Rating  Whiskey Rating     User
# Guinness           10            0               4  Testone
# Guinness           10            1               1  Testone

# %% [markdown]
# ### Find drink based on rating

# %%
rd.FindBest("Beer Rating", 10)
# Out:
# ['Guinness', 'Guinness']

# %%
rd.FindBest("Wine Rating", 6)
# Out:
# ['one']

# %%
rd.FindBest("Whiskey Rating", 9)
# Out:
# ['three']

# %% [markdown]
# ### Find ratings for each person

# %%
rd.FindName('User','Testone')
# Out:
#           Beer Rating  Wine Rating  Whiskey Rating     User
# Guinness           10            0               4  Testone
# Guinness           10            1               1  Testone
